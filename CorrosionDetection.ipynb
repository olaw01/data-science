# %% [markdown]
# <a href="https://colab.research.google.com/github/olaw01/data-science/blob/main/CorrosionDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %% [markdown]
# # Loading photos

# %% [markdown]
# # Contour detection

# %% [markdown]
# # Histograms
